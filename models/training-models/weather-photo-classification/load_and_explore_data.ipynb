# %% [markdown]
# # Weather Photo Classification
#
# In this excercise, you train a weather photo classifier by using Scikit-learn. Follow the instructions to train the model.
#
# > This exercise uses the _Weather phenomenon database (WEAPD)_. Dataset source: Xiao, Haixia, 2021, "Weather phenomenon database (WEAPD)", https://doi.org/10.7910/DVN/M8JQCR, Harvard Dataverse, V1. The dataset is also available in Kaggle: https://www.kaggle.com/datasets/jehanbhathena/weather-dataset/data.

# %% [markdown]
# ## 1. Import Packages
#
# Import the required packages for this exercise.

# %%
from pathlib import Path

import PIL
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Gather the Data
#
# Download the dataset from https://www.kaggle.com/datasets/jehanbhathena/weather-dataset/data.
#
# 1. Download the dataset ZIP file to your workstation.
# 2. Click the **Upload Files** icon in the file browser and upload the downloaded file to the workbench.
# Upload the file into the same directory as this notebook.
# You can verify the upload progress at the bottom tool bar.
# 3. When the upload is complete, unzip the file.

# %%
# !unzip -n -q archive.zip

# %% [markdown]
# ## 3. Inspect the Data
#
# Explore the directory structure:
# * The dataset organizes images across 11 weather classes.
# * The dataset uses one directory per class.

# %%
# !ls -l  dataset
# Out:
# total 204
# drwxr-sr-x. 2 1004370000 1004370000 20480 Mar 13 12:03 dew
# drwxr-sr-x. 2 1004370000 1004370000 20480 Mar 13 12:03 fogsmog
# drwxr-sr-x. 2 1004370000 1004370000 12288 Mar 13 12:03 frost
# drwxr-sr-x. 2 1004370000 1004370000 20480 Mar 13 12:03 glaze
# drwxr-sr-x. 2 1004370000 1004370000 20480 Mar 13 12:03 hail
# drwxr-sr-x. 2 1004370000 1004370000 12288 Mar 13 12:03 lightning
# drwxr-sr-x. 2 1004370000 1004370000 20480 Mar 13 12:03 rain
# drwxr-sr-x. 2 1004370000 1004370000  4096 Mar 13 12:03 rainbow
# drwxr-sr-x. 2 1004370000 1004370000 36864 Mar 13 12:03 rime
# drwxr-sr-x. 2 1004370000 1004370000 20480 Mar 13 12:03 sandstorm
# drwxr-sr-x. 2 1004370000 1004370000 20480 Mar 13 12:03 snow

# %% [markdown]
# Verify that these directories contain JPG images. Inspect the `rain` directory.

# %%
# !ls -l dataset/rain | tail
# Out:
# -rw-r--r--. 1 1004370000 1004370000   34463 Nov 26  2021 1819.jpg
# -rw-r--r--. 1 1004370000 1004370000  175890 Nov 26  2021 1820.jpg
# -rw-r--r--. 1 1004370000 1004370000  431689 Nov 26  2021 1821.jpg
# -rw-r--r--. 1 1004370000 1004370000   15921 Nov 26  2021 1822.jpg
# -rw-r--r--. 1 1004370000 1004370000   73833 Nov 26  2021 1823.jpg
# -rw-r--r--. 1 1004370000 1004370000   22209 Nov 26  2021 1824.jpg
# -rw-r--r--. 1 1004370000 1004370000  136156 Nov 26  2021 1825.jpg
# -rw-r--r--. 1 1004370000 1004370000  191518 Nov 26  2021 1826.jpg
# -rw-r--r--. 1 1004370000 1004370000   19714 Nov 26  2021 1827.jpg
# -rw-r--r--. 1 1004370000 1004370000  293758 Nov 26  2021 1828.jpg

# %% [markdown]
# Count the total number of images in the dataset.

# %%
datadir = Path("dataset")
len(list(datadir.glob("*/*.jpg")))
# Out:
# 6862

# %% [markdown]
# Preview one of the images in the dataset.

# %%
filename = "dataset/rain/1828.jpg"
image = PIL.Image.open(filename)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x810>

# %%
image.size
# Out:
# (1080, 810)

# %% [markdown]
# Continue the exercise by running the `data-prep_model-training-` notebooks.
