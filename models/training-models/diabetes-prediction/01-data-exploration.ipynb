# %% [markdown]
# # Analyzing Medical Data
#
# In this exercise, you train an ML model to determine whether a patient might have diabetes.
#
# The exercise uses the _Pima Indian Diabetes_ data set from the National Institute of Diabetes and Digestive and Kidney Diseases.
# The data set consists of approximately 800 cases of medical data for female patients with and without diabetes.
# The data includes features such as blood pressure, heart rate, and age.
# The data set is available as a CSV file in this repository.
#
# Explore the data to recognize whether you can use it to train a model that recognizes patients who have diabetes.
#
# > _NOTE:  In the interest of time, this notebook performs a simple and superficial analysis of the data.
# A more detailed study would require more time._
#
# ### 1. Import the required libraries and load the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the data set into a Pandas data frame called "data"
data = pd.read_csv("data/diabetes.csv")

# Obtain the length (rows) and width (columns) of the data set
data.shape
# Out:
# (768, 9)

# %% [markdown]
# The data contains 768 rows and 9 columns.
#
# Use the `head` method  of the Pandas dataframe to preview the first five rows.

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### 2. Inspect basic information.
#
# Use standard data analysis methods to start exploring the data.
#
# Inspect the column names and associated data types.
# The `info` method of a Pandas data frame displays the column names and data types in a data frame.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Note the different value types:
#
# * `Pregnancies`, `Glucose`, `BloodPressure`, `SkinThickness`, `Insulin`, `Age`, and `Outcome` contain integer values.
# * Body mass index(`BMI`) and `DiabetesPedigreeFuntion` contain float values.
#
# Use the `describe` method to see basic statistical information for each column, such as percentiles, mean, and standard deviation.

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# The dataset consists of several medical variables, which are the input features, and one target variable: `Outcome`.
#
# * `Pregnancies`:     Number of times pregnant
# * `Glucose`:         Plasma glucose concentration in an oral glucose tolerance test
# * `Blood Pressure`:  Diastolic blood pressure (mm Hg)
# * `SkinThickness`:   Triceps skin fold thickness (mm)
# * `Insulin`:         2-Hour serum insulin (mu U/ml)
# * `BMI`:             Body mass index (weight in kg/(height in m)^2)
# * `DiabetesPedigreeFunction` Probability of diabetes based on family history
# * `Age`:             Age (years)
# * `Outcome`:         Target variable. Whether the patient has diabetes (`1`) or not (`0`)

# %% [markdown]
# Count the number are diabetes cases.

# %%
data.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# 268 of 768 cases are diabetes cases.

# %% [markdown]
# ### 3. Identify missing data
#
# Plot the data to visualize the data distribution.
# Use the `hist` method to plot a histogram.
# You can use histograms to see how the data is distributed for each variable and detect outliers.

# %%
# Plot histograms of the columns on multiple subplots
plt.close('all')
data.hist(bins=20, figsize=(10, 8))
# Out:
# array([[<AxesSubplot: title={'center': 'Pregnancies'}>,
#         <AxesSubplot: title={'center': 'Glucose'}>,
#         <AxesSubplot: title={'center': 'BloodPressure'}>],
#        [<AxesSubplot: title={'center': 'SkinThickness'}>,
#         <AxesSubplot: title={'center': 'Insulin'}>,
#         <AxesSubplot: title={'center': 'BMI'}>],
#        [<AxesSubplot: title={'center': 'DiabetesPedigreeFunction'}>,
#         <AxesSubplot: title={'center': 'Age'}>,
#         <AxesSubplot: title={'center': 'Outcome'}>]], dtype=object)

# %% [markdown]
# The dataset is evenly distributed except for some outliers in `BMI`, `Blood Pressure`, and `DiabetesPedigreeFunction`.
#
# Additionally, note the high number of `0` values in the `SKinThickness` and `Insulin` features.
# In this particular scenario, the `0` values might indicate missing data for those features.

# %% [markdown]
# Reuse the `head` method to see the `0` values in the data. Print the first 20 rows.

# %%
data.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
# 15            7      100              0              0        0  30.0
# 16            0      118             84             47      230  45.8
# 17            7      107             74              0        0  29.6
# 18            1      103             30             38       83  43.3
# 19            1      115             70             30       96  34.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 0                      0.627   50        1
# 1                      0.351   31        0
# 2                      0.672   32        1
# 3                      0.167   21        0
# 4                      2.288   33        1
# 5                      0.201   30        0
# 6                      0.248   26        1
# 7                      0.134   29        0
# 8                      0.158   53        1
# 9                      0.232   54        1
# 10                     0.191   30        0
# 11                     0.537   34        1
# 12                     1.441   57        0
# 13                     0.398   59        1
# 14                     0.587   51        1
# 15                     0.484   32        1
# 16                     0.551   31        1
# 17                     0.254   31        1
# 18                     0.183   33        0
# 19                     0.529   32        1

# %% [markdown]
# Print the last 20 rows of the dataset and determine if those rows also contain `0` values.

# %%
data.tail(20)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 748                     0.408   36        1
# 749                     0.178   50        1
# 750                     1.182   22        1
# 751                     0.261   28        0
# 752                     0.223   25        0
# 753                     0.222   26        1
# 754                     0.443   45        1
# 755                     1.057   37        1
# 756                     0.391   39        0
# 757                     0.258   52        1
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %% [markdown]
# Determine the number of `0` values in the dataset.

# %%
# Select all the rows and only the feature columns
feature_data = data.iloc[:, :-1]

# Count the total number of rows
num_cases = data.shape[0]

# Number & percent of '0's for each feature
numZero = (feature_data[:] == 0).sum()
perZero = ((feature_data[:] == 0).sum())/num_cases*100

print(f"\nRows, Feature columns: {feature_data.shape}")
print("\n== Number of 0's:")
print(numZero)
print("\n == Percentage of 0's:")
print(perZero)
# Out:
# Rows, Feature columns: (768, 8)
#
# == Number of 0's:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64
#
#  == Percentage of 0's:
# Pregnancies                 14.453125
# Glucose                      0.651042
# BloodPressure                4.557292
# SkinThickness               29.557292
# Insulin                     48.697917
# BMI                          1.432292
# DiabetesPedigreeFunction     0.000000
# Age                          0.000000
# dtype: float64

# %% [markdown]
# The data set contains 227 zero values for `SkinThickness` and 374 zero values for `Insulin`.
# Aproximately half of the cases have missing insuling values.
#
# To build and train a reliable ML model, you should address these missing values.
# However, for the sake of simplicity, this exercise keeps the outliers in the dataset.
#
# Verify whether the missing data values are correlated to each other.

# %% [markdown]
# ### 4. Look for correlations
#
# Compute the _standard correlation coefficient_ between every pair of attributes by using the `corr` method.
# Note that, for bigger data sets, especially those with many features, computing the correlations might take a very long time.

# %%
corrM = data.corr()
corrM.style.background_gradient().format(precision=3)
# Out:
# <style type="text/css">
# #T_6c6f3_row0_col0, #T_6c6f3_row1_col1, #T_6c6f3_row2_col2, #T_6c6f3_row3_col3, #T_6c6f3_row4_col4, #T_6c6f3_row5_col5, #T_6c6f3_row6_col6, #T_6c6f3_row7_col7, #T_6c6f3_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6c6f3_row0_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_6c6f3_row0_col2, #T_6c6f3_row2_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_6c6f3_row0_col3, #T_6c6f3_row7_col4 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_6c6f3_row0_col4, #T_6c6f3_row0_col5, #T_6c6f3_row0_col6, #T_6c6f3_row2_col8, #T_6c6f3_row3_col0, #T_6c6f3_row3_col1, #T_6c6f3_row3_col7, #T_6c6f3_row6_col2, #T_6c6f3_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6c6f3_row0_col7 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_6c6f3_row0_col8, #T_6c6f3_row1_col6 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_6c6f3_row1_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_6c6f3_row1_col2, #T_6c6f3_row6_col8 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_6c6f3_row1_col3 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_6c6f3_row1_col4 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_6c6f3_row1_col5, #T_6c6f3_row3_col6, #T_6c6f3_row4_col6 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_6c6f3_row1_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_6c6f3_row1_col8 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_6c6f3_row2_col0, #T_6c6f3_row7_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_6c6f3_row2_col3 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_6c6f3_row2_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_6c6f3_row2_col5, #T_6c6f3_row6_col3 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_6c6f3_row2_col6 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_6c6f3_row2_col7 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_6c6f3_row3_col2, #T_6c6f3_row5_col1 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_6c6f3_row3_col4 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_6c6f3_row3_col5 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_6c6f3_row3_col8 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_6c6f3_row4_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_6c6f3_row4_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_6c6f3_row4_col2, #T_6c6f3_row6_col0 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_6c6f3_row4_col3 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_6c6f3_row4_col5 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_6c6f3_row4_col7, #T_6c6f3_row7_col6 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_6c6f3_row4_col8 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_6c6f3_row5_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_6c6f3_row5_col2, #T_6c6f3_row5_col4 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_6c6f3_row5_col3 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_6c6f3_row5_col6, #T_6c6f3_row8_col3 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_6c6f3_row5_col7 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_6c6f3_row5_col8 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_6c6f3_row6_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_6c6f3_row6_col4 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_6c6f3_row6_col5 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_6c6f3_row6_col7 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_6c6f3_row7_col0 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_6c6f3_row7_col1 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_6c6f3_row7_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_6c6f3_row7_col8 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_6c6f3_row8_col0, #T_6c6f3_row8_col5 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_6c6f3_row8_col1 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_6c6f3_row8_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_6c6f3_row8_col4 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_6c6f3_row8_col6 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_6c6f3_row8_col7 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# </style>
# <table id="T_6c6f3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c6f3_level0_col0" class="col_heading level0 col0" >Pregnancies</th>
#       <th id="T_6c6f3_level0_col1" class="col_heading level0 col1" >Glucose</th>
#       <th id="T_6c6f3_level0_col2" class="col_heading level0 col2" >BloodPressure</th>
#       <th id="T_6c6f3_level0_col3" class="col_heading level0 col3" >SkinThickness</th>
#       <th id="T_6c6f3_level0_col4" class="col_heading level0 col4" >Insulin</th>
#       <th id="T_6c6f3_level0_col5" class="col_heading level0 col5" >BMI</th>
#       <th id="T_6c6f3_level0_col6" class="col_heading level0 col6" >DiabetesPedigreeFunction</th>
#       <th id="T_6c6f3_level0_col7" class="col_heading level0 col7" >Age</th>
#       <th id="T_6c6f3_level0_col8" class="col_heading level0 col8" >Outcome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c6f3_level0_row0" class="row_heading level0 row0" >Pregnancies</th>
#       <td id="T_6c6f3_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_6c6f3_row0_col1" class="data row0 col1" >0.129</td>
#       <td id="T_6c6f3_row0_col2" class="data row0 col2" >0.141</td>
#       <td id="T_6c6f3_row0_col3" class="data row0 col3" >-0.082</td>
#       <td id="T_6c6f3_row0_col4" class="data row0 col4" >-0.074</td>
#       <td id="T_6c6f3_row0_col5" class="data row0 col5" >0.018</td>
#       <td id="T_6c6f3_row0_col6" class="data row0 col6" >-0.034</td>
#       <td id="T_6c6f3_row0_col7" class="data row0 col7" >0.544</td>
#       <td id="T_6c6f3_row0_col8" class="data row0 col8" >0.222</td>
#     </tr>
#     <tr>
#       <th id="T_6c6f3_level0_row1" class="row_heading level0 row1" >Glucose</th>
#       <td id="T_6c6f3_row1_col0" class="data row1 col0" >0.129</td>
#       <td id="T_6c6f3_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_6c6f3_row1_col2" class="data row1 col2" >0.153</td>
#       <td id="T_6c6f3_row1_col3" class="data row1 col3" >0.057</td>
#       <td id="T_6c6f3_row1_col4" class="data row1 col4" >0.331</td>
#       <td id="T_6c6f3_row1_col5" class="data row1 col5" >0.221</td>
#       <td id="T_6c6f3_row1_col6" class="data row1 col6" >0.137</td>
#       <td id="T_6c6f3_row1_col7" class="data row1 col7" >0.264</td>
#       <td id="T_6c6f3_row1_col8" class="data row1 col8" >0.467</td>
#     </tr>
#     <tr>
#       <th id="T_6c6f3_level0_row2" class="row_heading level0 row2" >BloodPressure</th>
#       <td id="T_6c6f3_row2_col0" class="data row2 col0" >0.141</td>
#       <td id="T_6c6f3_row2_col1" class="data row2 col1" >0.153</td>
#       <td id="T_6c6f3_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_6c6f3_row2_col3" class="data row2 col3" >0.207</td>
#       <td id="T_6c6f3_row2_col4" class="data row2 col4" >0.089</td>
#       <td id="T_6c6f3_row2_col5" class="data row2 col5" >0.282</td>
#       <td id="T_6c6f3_row2_col6" class="data row2 col6" >0.041</td>
#       <td id="T_6c6f3_row2_col7" class="data row2 col7" >0.240</td>
#       <td id="T_6c6f3_row2_col8" class="data row2 col8" >0.065</td>
#     </tr>
#     <tr>
#       <th id="T_6c6f3_level0_row3" class="row_heading level0 row3" >SkinThickness</th>
#       <td id="T_6c6f3_row3_col0" class="data row3 col0" >-0.082</td>
#       <td id="T_6c6f3_row3_col1" class="data row3 col1" >0.057</td>
#       <td id="T_6c6f3_row3_col2" class="data row3 col2" >0.207</td>
#       <td id="T_6c6f3_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_6c6f3_row3_col4" class="data row3 col4" >0.437</td>
#       <td id="T_6c6f3_row3_col5" class="data row3 col5" >0.393</td>
#       <td id="T_6c6f3_row3_col6" class="data row3 col6" >0.184</td>
#       <td id="T_6c6f3_row3_col7" class="data row3 col7" >-0.114</td>
#       <td id="T_6c6f3_row3_col8" class="data row3 col8" >0.075</td>
#     </tr>
#     <tr>
#       <th id="T_6c6f3_level0_row4" class="row_head

# %% [markdown]
# The data does not show strong correlations, which means that there is a notable degree of independency across the features.
#
# The `Pregnancies` and `Age` features have a moderate correlation.
#
# The `Insulin` and `SkinThickness` columns, which include many missing values, have a correlation value of 0.437, which might be caused by the high number `0` values in these two features.

# %% [markdown]
# ## References
#
# * Pima Indians Diabetes Database: Smith, J.W., Everhart, J.E., Dickson, W.C., Knowler, W.C., & Johannes, R.S. (1988). Using the ADAP learning algorithm to forecast the onset of diabetes mellitus. In Proceedings of the Symposium on Computer Applications and Medical Care (pp. 261--265). IEEE Computer Society Press. Available at: https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database
